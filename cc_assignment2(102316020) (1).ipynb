# %% [markdown]
# 1. Create a List L that is defined as= [10, 20, 30, 40, 50, 60, 70, 80].
# i. WAP to add 200 and 300 to L.
# ii. WAP to remove 10 and 30 from L.
# iii. WAP to sort L in ascending order.
# iv. WAP to sort L in descending order.

# %%
l=[10,20,30,40,50,60,70,80]
#add 200 and 300 to l.
l.append(200)
l.append(300)
print(l)
#remove 10 and 30 from l.
l.pop(0)

del l[1]
print(l)
#sort l in ascending order.
l.sort()
print(l)
#sort l in descending order.
l.sort(reverse=True)
print(l)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80, 200, 300]
# [20, 40, 50, 60, 70, 80, 200, 300]
# [20, 40, 50, 60, 70, 80, 200, 300]
# [300, 200, 80, 70, 60, 50, 40, 20]

# %% [markdown]
# 2. Create a tuple of marks scored as scores = (45, 89.5, 76, 45.4, 89, 92, 58, 45) and
# perform the following operations using tuple functions:
# i. Identify the highest score and its index in the tuple.
# ii. Find the lowest score and count how many times it appears.
# iii. Reverse the tuple and return it as a list.
# iv. Check if a specific score ‘76’ (input by the user) is present in the tuple and
# print its first occurrence index, or a message saying it’s not present.

# %%
t=(45, 89.5, 76, 45.4, 89, 92, 58, 45)
#Identify the highest score and its index in the tuple.
a=max(t)
print(a)
print(t.index(a))
#Find the lowest score and count how many times it appears.
b=min(t)
print(b)
print(t.count(b))
#Reverse the tuple and return it as a list.
print(list(reversed(t)))
#Check if a specific score ‘76’ (input by the user) is present in the tuple and print its first occurrence index, or a message saying it’s not present.
if 76 in t:
    print(t.index(76))
else:
    print("no index")
# Out:
# 92
# 5
# 45
# 2
# [45, 58, 92, 89, 45.4, 76, 89.5, 45]
# 2

# %% [markdown]
# 3. WAP to create a list of 100 random numbers between 100 and 900. Count and print
# the:
# i. All odd numbers
# ii. All even numbers
# iii. All prime numbers

# %%
#create a list of 100 random numbers between 100 and 900.
import random
l=[]
for i in range(101):
    l.append(random.randint(100,901))
print(l)
oddnum=[]
evennum=[]
primenum=[]
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True
for i in l:
    if i%2!=0:
        oddnum.append(i)
    if i%2==0:
        evennum.append(i)
    if is_prime(i):
        primenum.append(i)
#print the odd numbers
print(oddnum)
#print the even numbers
print(evennum)
#print the prime numbers
print(primenum)
#count the odd numbers
print(len(oddnum))
#count the even numbers
print(len(evennum))
#count the prime numbers
print(len(primenum))
# Out:
# [456, 158, 750, 295, 795, 381, 542, 489, 768, 429, 582, 788, 444, 678, 814, 148, 854, 306, 509, 141, 855, 335, 436, 734, 731, 383, 394, 612, 500, 449, 848, 245, 280, 384, 794, 572, 181, 873, 250, 347, 406, 486, 573, 428, 871, 792, 676, 317, 106, 689, 101, 855, 889, 815, 348, 824, 181, 152, 172, 605, 603, 383, 496, 242, 336, 613, 488, 625, 746, 502, 192, 478, 726, 174, 175, 873, 209, 773, 272, 756, 873, 861, 595, 151, 510, 721, 525, 104, 751, 392, 899, 627, 899, 598, 322, 388, 384, 831, 137, 132, 335]
# [295, 795, 381, 489, 429, 509, 141, 855, 335, 731, 383, 449, 245, 181, 873, 347, 573, 871, 317, 689, 101, 855, 889, 815, 181, 605, 603, 383, 613, 625, 175, 873, 209, 773, 873, 861, 595, 151, 721, 525, 751, 899, 627, 899, 831, 137, 335]
# [456, 158, 750, 542, 768, 582, 788, 444, 678, 814, 148, 854, 306, 436, 734, 394, 612, 500, 848, 280, 384, 794, 572, 250, 406, 486, 428, 792, 676, 106, 348, 824, 152, 172, 496, 242, 336, 488, 746, 502, 192, 478, 726, 174, 272, 756, 510, 104, 392, 598, 322, 388, 384, 132]
# [509, 383, 449, 181, 347, 317, 101, 181, 383, 613, 773, 151, 751, 137]
# 47
# 54
# 14

# %% [markdown]
# 4. Consider the following two sets, A and B, represenƟng scores of two teams in mulƟple
# matches. A = {34, 56, 78, 90} and B = {78, 45, 90, 23}
# WAP to perform the following operaƟons using set funcƟons:
# i. Find the unique scores achieved by both teams (union of sets).
# ii. IdenƟfy the scores that are common to both teams (intersecƟon of sets).
# iii. Find the scores that are exclusive to each team (symmetric difference).
# iv. Check if the scores of team A are a subset of team B, and if team B's scores are
# a superset of team A.
# v. Remove a specific score X (input by the user) from set A if it exists. If not, print
# a message saying it is not present.

# %%
A = {34, 56, 78, 90}
B = {78, 45, 90, 23}
#UNION OF TWO SETS
print(A.union(B))
#INTERSECTION OF 2 SETS
print(A.intersection(B))
#SYMMETRIC DIFFERENCE OF TWO SETS
print(A.symmetric_difference(B))
#check if a is the subset of b and b is the superset of a
print(A.issubset(B))
print(B.issuperset(A))
#Remove a specific score X (input by the user) from set A if it exists. If not, printa message saying it is not present.
x=int(input("enter the number:"))
if x in A:
    A.remove(x)
else:
    print("it is not present")
# Out:
# {34, 45, 78, 23, 56, 90}
# {90, 78}
# {34, 45, 23, 56}
# False
# False
# enter the number: 33
# it is not present

# %% [markdown]
# 5. Write a program to rename a key city to a location in the following dicƟonary.
# ![image.png](attachment:9131558b-e73b-41b8-b604-7974cb681171.png)

# %%
sample_dict={
    "name":"kelly","age":25,"salary":8000,"city":"New York"}
sample_dict["location"]=sample_dict.pop("city")
print(sample_dict)
# Out:
# {'name': 'kelly', 'age': 25, 'salary': 8000, 'location': 'New York'}
